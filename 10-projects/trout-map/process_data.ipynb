# %%
import pandas as pd

# %%
fn = 'observations-mt-09-07-25'
df = pd.read_csv(f"data/{fn}.csv")
# find nan
df[df['scientific_name'].isna()]
# Out:
#              id                                  uuid  \
# 663   165716587  608032e8-24be-48ec-904b-b2c571ff648f
# 700   170444948  fe14c2c9-ee6a-4cca-94a1-5586adbe2651
# 1132  278621315  3af34fa9-3399-4127-9baa-e3fc4e0a11d5
#
#                             observed_on_string observed_on  \
# 663                        2023-06-05 07:54:33  2023-06-05
# 700   Wed Jun 28 2023 09:10:22 GMT -0600 (MDT)  2023-06-28
# 1132                 2024-12-29 15:27:12-07:00  2024-12-29
#
#              time_observed_at                    time_zone  user_id  \
# 663   2023-06-05 13:54:33 UTC  Mountain Time (US & Canada)  5340698
# 700   2023-06-28 15:10:22 UTC  Mountain Time (US & Canada)  4765727
# 1132  2024-12-29 22:27:12 UTC  Mountain Time (US & Canada)  8878152
#
#        user_login      user_name               created_at  ... geoprivacy  \
# 663      mindy136  Mindy Ferrell  2023-06-05 13:53:35 UTC  ...        NaN
# 700      firechf3            NaN  2023-07-01 13:54:39 UTC  ...        NaN
# 1132  tanner-nead            NaN  2025-05-05 02:02:40 UTC  ...        NaN
#
#      taxon_geoprivacy coordinates_obscured positioning_method  \
# 663               NaN                False                NaN
# 700               NaN                False                NaN
# 1132              NaN                False                NaN
#
#      positioning_device species_guess scientific_name common_name  \
# 663                 NaN           NaN             NaN         NaN
# 700                 NaN           NaN             NaN         NaN
# 1132                NaN           NaN             NaN         NaN
#
#       iconic_taxon_name  taxon_id
# 663                 NaN       NaN
# 700                 NaN       NaN
# 1132                NaN       NaN
#
# [3 rows x 40 columns]

# %%
fn = 'observations-us-09-07-25'
df = pd.read_csv(f"data/{fn}.csv")
df = df[~df['scientific_name'].isna()]
genus_to_keep = ['Oncorhynchus', 'Salmo', 'Salvelinus']
df = df[df['scientific_name'].str.startswith(tuple(genus_to_keep))]

species_to_remove = [
    'Oncorhynchus tshawytscha',
    'Oncorhynchus kisutch',
    'Oncorhynchus nerka',
    'Oncorhynchus gorbuscha',
    'Oncorhynchus keta',
    'Salmo salar'
    ]

# remove species_to_remove
df = df[~df['scientific_name'].isin(species_to_remove)]

# require image_url to be non-null
df = df[df['image_url'].notna()]

columns_to_drop = [
    'uuid',
    'observed_on_string',
    'time_observed_at',
    'time_zone',
    'user_id',
    'user_login',
    'user_name',
    'created_at',
    'updated_at',
    'quality_grade',
    'license',
    'sound_url',
    'tag_list',
    'num_identification_agreements',
    'num_identification_disagreements',
    'captive_cultivated',
    'oauth_application_id',
    'place_guess',
    'private_place_guess',
    'private_latitude',
    'private_longitude',
    'positioning_method',
    'positioning_device',
    'public_positional_accuracy',
    'positional_accuracy',
    'taxon_geoprivacy'
    ]


# Create a mapping dictionary
name_mapping = {
    # Rainbow Trout variants
    'Rainbow Trout': 'Rainbow Trout',
    'Coastal Rainbow Trout': 'Rainbow Trout',
    'Kern River Rainbow Trout': 'Rainbow Trout',
    'Eagle Lake Rainbow Trout': 'Rainbow Trout',
    'Kamloops Rainbow Trout': 'Rainbow Trout',

    # Redband Trout variants
    'Sacramento Redband Trout': 'Redband Trout',
    'McCloud River Redband Trout': 'Redband Trout',
    'Columbia River Redband Trout': 'Redband Trout',
    'Great Basin Redband Trout': 'Redband Trout',
    
    # Golden Trout variants
    'Golden Trout': 'Golden Trout',
    'California Golden Trout': 'Golden Trout',
    'Little Kern Golden Trout': 'Golden Trout',
    
    # Cutthroat Trout variants
    'Coastal Cutthroat Trout': 'Cutthroat Trout',
    'Lahontan Cutthroat Trout': 'Cutthroat Trout',
    'Paiute Cutthroat Trout': 'Cutthroat Trout',
    'Rocky Mountain Cutthroat Trout': 'Cutthroat Trout',
    'Rio Grande Cutthroat Trout': 'Cutthroat Trout',
    'Colorado River Cutthroat Trout': 'Cutthroat Trout',
    'Snake River Fine-spotted Cutthroat Trout': 'Cutthroat Trout',
    'Greenback Cutthroat Trout': 'Cutthroat Trout',
    'Bonneville Cutthroat Trout': 'Cutthroat Trout',
    'Humboldt Cutthroat Trout': 'Cutthroat Trout',
    'Yellowstone Cutthroat Trout': 'Cutthroat Trout',
    'Westslope Cutthroat Trout': 'Cutthroat Trout',
    
    # Keep these distinct
    'Brook Trout': 'Brook Trout',
    'Brown Trout': 'Brown Trout',
    'River Brown Trout': 'Brown Trout',
    'Lake Trout': 'Lake Trout',
    'Bull Trout': 'Bull Trout',
    'Dolly Varden': 'Dolly Varden',
    'Apache Trout': 'Apache Trout',
    'Gila Trout': 'Gila Trout',
    
    # Hybrids
    'Golden × Rainbow Trout': 'Golden × Rainbow Hybrid',
    'Arctic Char × Brook Trout': 'Arctic Char × Brook Hybrid',
    'Brook × Bull Trout': 'Brook × Bull Hybrid',
    'Tiger Trout': 'Tiger Trout',
    'Lahontan Cutbow': 'Cutbow Hybrid',
    'Rocky Mountain Cutbow': 'Cutbow Hybrid',
    'Westslope Cutbow': 'Cutbow Hybrid',
    'Splake': 'Splake',
    'Coastal Cutbow': 'Cutbow Hybrid',
    
    # Salmonid categories
    'Pacific Salmons and Trouts': 'Unspecified',
    'Salmons and Trouts': 'Unspecified',
    'Salmons, Trouts, and Whitefishes': 'Unspecified',
    'Atlantic Salmons and Trouts': 'Unspecified',
    'Chinook Salmon': 'Salmon',
    'Coho Salmon': 'Salmon',
    'Sockeye Salmon': 'Salmon',
    'Pink Salmon': 'Salmon',
    'Chum Salmon': 'Salmon',
    'Atlantic Salmon': 'Salmon',
}

# Apply the mapping
df['generic_name'] = df['common_name'].map(name_mapping)

# Check for any unmapped values (in case there are names not in your list)
unmapped = df[df['generic_name'].isna()]['common_name'].unique()
if len(unmapped) > 0:
    print(f"Warning: Unmapped common names found: {unmapped}")

# Optional: fill any unmapped values with the original name
df['generic_name'] = df['generic_name'].fillna(df['common_name'])

# See the distribution of generic names
print(df['generic_name'].value_counts())
print(len(df))
#df = df.drop(columns=columns_to_drop)
df.to_csv(f'data/{fn}-clean.csv', index=False)
# Out:
# Warning: Unmapped common names found: [nan 'Chars' 'Arctic Char' 'Pink × Chum Salmon']
# generic_name
# Rainbow Trout                 13589
# Brook Trout                    7208
# Brown Trout                    5734
# Cutthroat Trout                3779
# Unspecified                    3615
# Redband Trout                   979
# Lake Trout                      543
# Golden Trout                    346
# Tiger Trout                     321
# Dolly Varden                    288
# Bull Trout                      242
# Cutbow Hybrid                   101
# Gila Trout                       68
# Splake                           56
# Chars                            36
# Arctic Char                      36
# Apache Trout                     33
# Golden × Rainbow Hybrid          19
# Brook × Bull Hybrid              10
# Pink × Chum Salmon                3
# Arctic Char × Brook Hybrid        1
# Name: count, dtype: int64
# 37050

# %%
fn = 'observations-us-09-07-25'
df = pd.read_csv(f"data/{fn}.csv")
df = df[~df['scientific_name'].isna()]
genus_to_keep = ['Oncorhynchus', 'Salmo', 'Salvelinus']
df = df[df['scientific_name'].str.startswith(tuple(genus_to_keep))]
df[~df['scientific_name'].isin(tuple(species_to_remove))]['scientific_name'].value_counts()
# Out:
# scientific_name
# Oncorhynchus mykiss                     12474
# Salvelinus fontinalis                    7286
# Salmo trutta                             5776
# Oncorhynchus                             2729
# Oncorhynchus keta                        1341
# Oncorhynchus mykiss irideus              1242
# Oncorhynchus gorbuscha                   1072
# Oncorhynchus clarkii                     1026
# Oncorhynchus virginalis                   919
# Salmoninae                                889
# Oncorhynchus mykiss gairdneri             874
# Oncorhynchus lewisi                       675
# Salvelinus namaycush                      561
# Oncorhynchus virginalis utah              376
# Salmo trutta × Salvelinus fontinalis      323
# Salvelinus malma                          291
# Oncorhynchus virginalis bouvieri          284
# Salmo salar                               255
# Salvelinus confluentus                    246
# Oncorhynchus aguabonita                   216
# Oncorhynchus virginalis pleuriticus       172
# Oncorhynchus henshawi henshawi            105
# Oncorhynchus aguabonita aguabonita        100
# Oncorhynchus virginalis behnkei            89
# Oncorhynchus virginalis virginalis         87
# Oncorhynchus gilae                         68
# Oncorhynchus mykiss × virginalis           68
# Salvelinus namaycush × fontinalis          57
# Oncorhynchus henshawi                      56
# Salvelinus fontinalis fontinalis           44
# Oncorhynchus mykiss calisulat              40
# Oncorhynchus mykiss stonei                 40
# Salvelinus                                 37
# Salvelinus alpinus                         36
# Oncorhynchus apache                        33
# Oncorhynchus aguabonita gilberti           33
# Oncorhynchus aguabonita whitei             31
# Salmo                                      26
# Oncorhynchus mykiss × lewisi               26
# Oncorhynchus mykiss newberrii              25
# Oncorhynchus aguabonita × mykiss           19
# Salmo trutta fario                         15
# Oncorhynchus virginalis stomias            13
# Salvelinus confluentus × fontinalis        11
# Oncorhynchus henshawi humboldtensis         9
# Oncorhynchus mykiss aquilarum               6
# Oncorhynchus mykiss kamloops                5
# Oncorhynchus mykiss × clarkii               5
# Oncorhynchus gorbuscha × keta               3
# Oncorhynchus henshawi seleniris             3
# Oncorhynchus mykiss × henshawi              2
# Salvelinus alpinus × fontinalis             1
# Name: count, dtype: int64

# %%
import pandas as pd
test = pd.read_csv('/Users/clkruse/Downloads/0046034-250827131500795.csv')
test.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 test = pd.read_csv('/Users/clkruse/Downloads/0046034-250827131500795.csv')
#       3 test.head()
#
# File ~/miniforge3/envs/core/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/core/lib/python3.10/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/miniforge3/envs/core/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/miniforge3/envs/core/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 18, saw 3
